# %%
import pandas as pd
df = pd.read_csv("en.openfoodfacts.org.products.csv", sep='\t', error_bad_lines=False, usecols = ['code', 'categories', 'nutriscore_grade', 'nova_group', 'energy-kj_100g', 'carbohydrates_100g', 'sugars_100g', 'fat_100g', 'saturated-fat_100g', 'proteins_100g', 'fiber_100g','sodium_100g','alcohol_100g'], dtype='unicode')
                                            
df.head(50)
# Out:
#                     code                                         categories  \
# 0      00000000000000225                                                NaN
# 1   00000000000003429145                                                NaN
# 2          0000000000017                                                NaN
# 3          0000000000031                                                NaN
# 4     000000000003327986                                                NaN
# 5     000000000004622327                                                NaN
# 6          0000000000100            Epicerie, Condiments, Sauces, Moutardes
# 7   00000000001111111111                                                Xsf
# 8          0000000000123                                                NaN
# 9          0000000000178                                                NaN
# 10         0000000000208                                                NaN
# ...

# %%
# Liens utiles

#https://www.kaggle.com/apryor6/detailed-cleaning-visualization-python
#https://www.kaggle.com/sajal0jain/detailed-data-exploration-in-python
#https://www.kaggle.com/deffro/eda-is-fun
#https://github.com/wesm/pydata-book
#https://www.youtube.com/watch?v=u64sWJEP4S0
#https://plotly.com/python/plotly-express/

#Data visualisation best practice: 
#https://www.youtube.com/watch?v=OW3oco7nlV4&list=PL_pVmAaAnxIRnSw6wiCpSvshFyCREZmlM&index=3
#https://clauswilke.com/dataviz/

#https://quoidansmonassiette.fr/wp-content/uploads/2018/05/Infographie-calcul-nutriscore-logo-nutritionnel-score-corrig%C3%A9-scaled.jpg

# %%
# Pourcentage de ligne avec une valeur de nutriscore
a = df['nutriscore_grade'].isna().sum()
b = df.shape[0] 
c = ((b-a)/b)*100
print(c)
# Out:
# 36.43285193488322

# %%
df_nutriscore = df[ df['nutriscore_grade'].notna() ]
df_nutriscore.to_csv('df_nutriscore.csv')

# %%
df_nutriscore.head(50)
# Out:
#               code                                         categories  \
# 6    0000000000100            Epicerie, Condiments, Sauces, Moutardes
# 17   0000000000949  Plats préparés, Légumes préparés, Carottes râp...
# 26   0000000001281   Tartes, Tartes sucrées, Tartes à la noix de coco
# 36   0000000001885  Aliments et boissons à base de végétaux, Alime...
# 40   0000000002257  Plats préparés, Légumes préparés, Entrées, Ent...
# 65   0000000005005  Produits laitiers, Produits fermentés, Produit...
# 67   0000000005166     Viandes, Volailles, Poulets, Cuisses de poulet
# 68   0000000005241  Aliments et boissons à base de végétaux, Alime...
# 71   0000000005470  Aliments et boissons à base de végétaux, Alime...
# 73   0000000005661  Produits de la mer, Poissons, Saumons, Poisson...
# 75   0000000007160  Conserves, Viandes, Plats préparés, Produits à...
# 95   0000000012249         Plats préparés, Salades, Salades composées
# ...

# %%
df_nutriscore.shape[0]
# Out:
# 705955

# %%
import pandas as pd
df_nutriscore = pd.read_csv("df_nutriscore.csv")
# Out:
# /Users/benprieur/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import matplotlib.pyplot as plt
df_nutriscore.groupby('nutriscore_grade').nutriscore_grade.value_counts().plot.barh()
# Out:
# <AxesSubplot:ylabel='nutriscore_grade,nutriscore_grade'>

# %%
# https://medium.com/data-science-365/pandas-for-data-science-part-2-c12c3ee876c2
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Saturated Fat')
plt.ylabel('Density')
dft = df_nutriscore
dft['saturated'] = dft['saturated-fat_100g']
dft = dft.query("saturated >= 0 and saturated <= 100")
sns.kdeplot(dft['saturated'])
# Out:
# <AxesSubplot:xlabel='Saturated Fat', ylabel='Density'>

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Fat')
plt.ylabel('Density')
dft = df_nutriscore.query("fat_100g >= 0 and fat_100g <= 100")
sns.kdeplot(dft['fat_100g'])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Carbohydrates')
plt.ylabel('Density')
dft = df_nutriscore.query("carbohydrates_100g >= 0 and carbohydrates_100g <= 100")
sns.kdeplot(dft['carbohydrates_100g'])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Sugar')
plt.ylabel('Density')
dft = df_nutriscore.query("sugars_100g >= 0 and sugars_100g <= 100")
sns.kdeplot(dft['sugars_100g'])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Proteins')
plt.ylabel('Density')
dft = df_nutriscore.query("proteins_100g >= 0 and proteins_100g <= 100")
sns.kdeplot(dft['proteins_100g'])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Sodium')
plt.ylabel('Density')
dft = df_nutriscore.query("sodium_100g >= 0 and sodium_100g <= 100")
sns.kdeplot(dft['sodium_100g'])
plt.show()

# %%
# Une incursion du côté du nova group
df_nutriscore_nova = df_nutriscore[ df_nutriscore['nova_group'].notna() ]
df_nutriscore_nova.to_csv('df_nutriscore_nova.csv')

# %%
import pandas as pd
df_nutriscore_nova = pd.read_csv("df_nutriscore_nova.csv")
# Out:
# /Users/benprieur/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_nutriscore_nova.shape[0]
# Out:
# 462468

# %%
import matplotlib.pyplot as plt
df_nutriscore_nova.groupby('nutriscore_grade').nutriscore_grade.value_counts().plot.barh()
# Out:
# <AxesSubplot:ylabel='nutriscore_grade,nutriscore_grade'>

# %%
import matplotlib.pyplot as plt
df_nutriscore_nova.groupby('nova_group').nova_group.value_counts().plot.barh()
# Out:
# <AxesSubplot:ylabel='nova_group,nova_group'>

# %%
# https://medium.com/swlh/how-to-run-chi-square-test-in-python-4e9f5d10249d
contigency = pd.crosstab(df_nutriscore_nova['nutriscore_grade'], df_nutriscore_nova['nova_group']) 
print(contigency)
# Out:
# nova_group          1.0   2.0    3.0     4.0
# nutriscore_grade
# a                 32873   302  21245   23658
# b                  7826   142  15326   35934
# c                  7079  2095  25003   62444
# d                  2783  1973  34992  101212
# e                  1628  1542  13281   71130

# %%
contigency_pct = pd.crosstab(df_nutriscore_nova['nutriscore_grade'], df_nutriscore_nova['nova_group'], normalize='index')
print(contigency_pct)
# Out:
# nova_group             1.0       2.0       3.0       4.0
# nutriscore_grade
# a                 0.421028  0.003868  0.272100  0.303005
# b                 0.132133  0.002398  0.258763  0.606706
# c                 0.073266  0.021683  0.258774  0.646278
# d                 0.019743  0.013997  0.248241  0.718019
# e                 0.018589  0.017607  0.151642  0.812162

# %%
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency_pct, annot=False, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='nova_group', ylabel='nutriscore_grade'>

# %%
from scipy.stats import chi2_contingency
c, p, dof, expected = chi2_contingency(contigency_pct) 
print(p)
# Out:
# 0.9999692943362465

# %%
# 0.9999692943362465 >> 0.01
# Le test n'est pas validé : pas d'indépendance ; nova et nutriscore sont corrélées.

# %%
df_nutriscore_sodium = df_nutriscore[ df_nutriscore['sodium_100g'].notna() ]
#df_nutriscore_sodium.head(50)
modalites = sorted(df_nutriscore_sodium['nutriscore_grade'].unique())
print(modalites)

groupes = []
for m in modalites:
    groupes.append(df_nutriscore_sodium[df_nutriscore_sodium['nutriscore_grade']==m]['sodium_100g'])
    
medianprops = {'color':"black"}
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}
    
plt.boxplot(groupes, labels=modalites, showfliers=False, medianprops=medianprops, 
            vert=False, patch_artist=True, showmeans=True, meanprops=meanprops)
plt.show()
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
df_nutriscore_sodium = df_nutriscore[ df_nutriscore['fat_100g'].notna() ]
#df_nutriscore_sodium.head(50)
modalites = sorted(df_nutriscore_sodium['nutriscore_grade'].unique())
print(modalites)

groupes = []
for m in modalites:
    groupes.append(df_nutriscore_sodium[df_nutriscore_sodium['nutriscore_grade']==m]['fat_100g'])
    
medianprops = {'color':"black"}
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}
    
plt.boxplot(groupes, labels=modalites, showfliers=False, medianprops=medianprops, 
            vert=False, patch_artist=True, showmeans=True, meanprops=meanprops)
plt.show()
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
df_nutriscore_sodium = df_nutriscore[ df_nutriscore['saturated-fat_100g'].notna() ]
#df_nutriscore_sodium.head(50)
modalites = sorted(df_nutriscore_sodium['nutriscore_grade'].unique())
print(modalites)

groupes = []
for m in modalites:
    groupes.append(df_nutriscore_sodium[df_nutriscore_sodium['nutriscore_grade']==m]['saturated-fat_100g'])
    
medianprops = {'color':"black"}
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}
    
plt.boxplot(groupes, labels=modalites, showfliers=False, medianprops=medianprops, 
            vert=False, patch_artist=True, showmeans=True, meanprops=meanprops)
plt.show()
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
dftest = df_nutriscore[ df_nutriscore['fat_100g'].notna() ]
dftest = dftest[ dftest['sodium_100g'].notna() ]
dftest.shape[0]
# Out:
# 703889

# %%
dftest2 = dftest.query("fat_100g >= 0 and fat_100g <= 100")
dftest2.shape[0]
# Out:
# 703876

# %%
dftest3 = dftest2.query("sodium_100g >= 0 and sodium_100g <= 100")
dftest3.shape[0]
# Out:
# 703728

# %%
sns.relplot(x='fat_100g', y='sodium_100g', data=dftest3, hue='nutriscore_grade')

# %%
dftest3['saturated'] = dftest3['saturated-fat_100g']
dftest4 = dftest3.query("saturated >= 0 and saturated <= 100")
dftest4.shape[0]
# Out:
# <ipython-input-173-b0c5aa294470>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftest3['saturated'] = dftest3['saturated-fat_100g']
# 703666

# %%
sns.relplot(x='saturated', y='sodium_100g', data=dftest4, hue='nutriscore_grade')

# %%
codebarre = '0000000002257' #'0000000001281'
#print(codebarre)
#df_nutriscore.head(50)

dfcode = df_nutriscore[df_nutriscore.code==codebarre]
if (dfcode.shape[0] != 1):
    print("Pas de code barre correspondant")
    
product = dfcode.iloc[0]
#print(product.categories)
category = product.categories.split(', ')[0]
print(category)
nutriscore = product.nutriscore_grade
print(nutriscore)

dfresult = df_nutriscore[df_nutriscore['categories'].str.startswith(category, na=False)]
dfresult = dfresult[dfresult['nutriscore_grade'] < nutriscore]
dfresult.sort_values(by=['nutriscore_grade'], ascending=True)
dfresult.shape[0]
print ("--------------")
substitute = dfresult.iloc[0]
print (substitute)
# Out:
# Plats préparés
# b
# --------------
# Unnamed: 0                                                         1648
# code                                                           00012232
# categories            Plats préparés, Plats à base de pâtes, Salades...
# nutriscore_grade                                                      a
# nova_group                                                          4.0
# energy-kj_100g                                                      NaN
# fat_100g                                                            2.3
# saturated-fat_100g                                                  0.4
# carbohydrates_100g                                                 13.0
# sugars_100g                                                         1.1
# fiber_100g                                                          1.7
# proteins_100g                                                       5.6
# sodium_100g                                                         0.2
# ...
