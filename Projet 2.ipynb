# %%
import pandas as pd
df = pd.read_csv("en.openfoodfacts.org.products.csv", sep='\t', error_bad_lines=False, usecols = ['code', 'nutriscore_grade', 'nova_group', 'energy-kj_100g', 'carbohydrates_100g', 'sugars_100g', 'fat_100g', 'saturated-fat_100g', 'proteins_100g', 'fiber_100g','sodium_100g','alcohol_100g'], dtype='unicode')
                                            
df.head(50)
# Out:
#                     code nutriscore_grade nova_group energy-kj_100g fat_100g  \
# 0      00000000000000225              NaN        NaN            NaN      NaN
# 1   00000000000003429145              NaN        NaN            NaN      1.4
# 2          0000000000017              NaN        NaN            NaN        7
# 3          0000000000031              NaN        NaN            NaN      NaN
# 4     000000000003327986              NaN        NaN          685.8      1.9
# 5     000000000004622327              NaN        NaN            NaN     15.1
# 6          0000000000100                d        NaN            936      8.2
# 7   00000000001111111111              NaN        NaN            NaN      NaN
# 8          0000000000123              NaN        NaN            NaN        0
# 9          0000000000178              NaN        NaN            NaN        3
# 10         0000000000208              NaN        NaN            NaN      NaN
# 11         0000000000284              NaN        NaN            NaN      NaN
# 12         0000000000291              NaN        NaN            NaN      NaN
# 13          000000000054              NaN        NaN            NaN      NaN
# 14          000000000075              NaN        NaN            NaN      NaN
# 15          000000000080              NaN        NaN            NaN        0
# 16          000000000088              NaN        NaN            NaN      NaN
# 17         0000000000949                b        NaN            NaN      0.3
# 18         0000000000970              NaN        NaN            NaN      4.9
# 19         0000000001001              NaN        NaN            NaN      NaN
# 20         0000000001007              NaN        NaN            NaN      NaN
# 21          000000000112              NaN        NaN            NaN      4.3
# 22         0000000001137              NaN        NaN            NaN      3.3
# 23          000000000114              NaN        NaN            NaN       44
# 24         0000000001151              NaN        NaN            NaN      9.4
# 25         0000000001199              NaN          4            NaN      5.9
# 26         0000000001281                d        NaN            NaN       22
# 27          000000000129              NaN        NaN            NaN       25
# 28         0000000001311              NaN        NaN            NaN        0
# 29         0000000001328              NaN        NaN            NaN       21
# 30         0000000001427              NaN        NaN            NaN      NaN
# 31         0000000001526              NaN        NaN            NaN      NaN
# 32         0000000001564              NaN        NaN            NaN      3.3
# 33         0000000001663              NaN          4            NaN        0
# 34         0000000001670              NaN        NaN            NaN      NaN
# 35          000000000186              NaN        NaN            NaN      4.3
# 36         0000000001885                a        NaN            NaN        0
# 37         0000000002042              NaN        NaN            NaN      9.1
# 38         0000000002103              NaN        NaN            NaN      NaN
# 39         0000000002219              NaN        NaN            NaN      2.2
# 40         0000000002257                b        NaN            NaN     12.7
# 41         0000000002264              NaN          4            NaN      6.7
# 42         0000000002363              NaN        NaN            NaN      3.7
# 43         0000000002400              NaN        NaN            NaN      2.3
# 44         0000000002417              NaN        NaN            NaN      4.5
# 45         0000000003018              NaN        NaN            NaN      0.2
# 46         0000000003087              NaN        NaN            NaN      NaN
# 47         0000000003384              NaN        NaN            NaN      5.6
# 48          000000000364              NaN        NaN            NaN      NaN
# 49         0000000003780              NaN        NaN            NaN        2
#
#    saturated-fat_100g carbohydrates_100g sugars_100g fiber_100g proteins_100g  \
# 0                 NaN                NaN         NaN        NaN           NaN
# 1                 0.9                9.8         9.8        NaN           2.7
# 2                3.08               70.1          15        NaN           7.8
# 3                 NaN                NaN         NaN        NaN           NaN
# 4                   1                NaN         NaN        NaN          15.3
# 5                 6.1                2.6           1        NaN          15.7
# 6                 2.2                 29          22          0           5.1
# 7                 NaN                NaN         NaN        NaN           NaN
# 8                   0                4.8         0.4        NaN           0.2
# 9                   1                 10           3        NaN             2
# 10                NaN                NaN         NaN        NaN           NaN
# 11                NaN                NaN         NaN        NaN           NaN
# 12                NaN                NaN         NaN        NaN           NaN
# 13                NaN                NaN         NaN        NaN           NaN
# 14                NaN                NaN         NaN        NaN           NaN
# 15                  0               15.5        15.5        NaN           0.2
# 16                NaN                NaN         NaN        NaN           NaN
# 17                0.1                5.3         3.9        NaN           0.9
# 18                3.1               16.3        16.3        NaN           4.4
# 19                NaN                NaN         NaN        NaN           NaN
# 20                NaN                NaN         NaN        NaN           NaN
# 21                  3                4.3         1.6        NaN           3.3
# 22                2.1               38.4         1.8        NaN          11.7
# 23                 28                 30          27        NaN           2.1
# 24                4.5                 41           2        NaN          12.5
# 25                0.5               30.3         1.7        2.8           9.7
# 26               15.5               27.3        21.9        4.4           4.6
# 27                4.9                 58          44        NaN           0.8
# 28                  0                 24          23        NaN             0
# 29                 12                 39          20        NaN           7.8
# 30                NaN                NaN         NaN        NaN           NaN
# 31                NaN                NaN         NaN        NaN           NaN
# 32                3.3                7.6         7.5        NaN           4.6
# 33                  0                  0           0        NaN             0
# 34                NaN                NaN         NaN        NaN           NaN
# 35                1.2               17.1        12.7        NaN           2.7
# 36                  0                 36          27        3.6           0.6
# 37                2.5                9.2         0.9        NaN           8.3
# 38                NaN                NaN         NaN        NaN           NaN
# 39                0.5                5.2         1.2        NaN             7
# 40                  1                3.9           1        NaN           1.9
# 41                3.8               27.5         0.6        1.7           8.9
# 42                  1               20.7         3.8        NaN           9.1
# 43                0.4               29.3         1.4        NaN           8.9
# 44                2.1               31.5           1        NaN          12.5
# 45                0.1                2.2         2.1        NaN           0.9
# 46                NaN                NaN         NaN        NaN           NaN
# 47                  0               22.7        21.6        NaN           5.8
# 48                NaN                NaN         NaN        NaN           NaN
# 49                  1                 10          10        NaN             2
#
#    sodium_100g alcohol_100g
# 0          NaN          NaN
# 1         0.04          NaN
# 2         0.56          NaN
# 3          NaN          NaN
# 4         0.44          NaN
# 5         0.84          NaN
# 6         1.84          NaN
# 7          NaN          NaN
# 8        0.816          NaN
# 9         0.46          NaN
# 10         NaN          NaN
# 11         NaN          NaN
# 12         NaN          NaN
# 13         NaN          NaN
# 14           0          NaN
# 15           0          NaN
# 16           0          NaN
# 17       0.168          NaN
# 18         0.1          NaN
# 19         NaN          NaN
# 20         NaN          NaN
# 21        0.04          NaN
# 22      0.2712          NaN
# 23        0.01          NaN
# 24        0.36          NaN
# 25      0.1856          NaN
# 26        0.04          NaN
# 27         0.2          NaN
# 28        1.28          NaN
# 29         0.6          NaN
# 30         NaN          NaN
# 31         NaN          NaN
# 32      0.0108          NaN
# 33           0          NaN
# 34         NaN          NaN
# 35        0.04          NaN
# 36           0          NaN
# 37        1.12          NaN
# 38         NaN          NaN
# 39       0.072          NaN
# 40       0.108          NaN
# 41        0.16          NaN
# 42      0.0776          NaN
# 43      0.2124          NaN
# 44       1.804          NaN
# 45           2          NaN
# 46         NaN          NaN
# 47      0.1772          NaN
# 48           0          NaN
# 49         3.6          NaN

# %%
# Liens utiles

#https://www.kaggle.com/apryor6/detailed-cleaning-visualization-python
#https://www.kaggle.com/sajal0jain/detailed-data-exploration-in-python
#https://www.kaggle.com/deffro/eda-is-fun
#https://github.com/wesm/pydata-book
#https://www.youtube.com/watch?v=u64sWJEP4S0
#https://plotly.com/python/plotly-express/

#Data visualisation best practice: 
#https://www.youtube.com/watch?v=OW3oco7nlV4&list=PL_pVmAaAnxIRnSw6wiCpSvshFyCREZmlM&index=3
#https://clauswilke.com/dataviz/

#https://quoidansmonassiette.fr/wp-content/uploads/2018/05/Infographie-calcul-nutriscore-logo-nutritionnel-score-corrig%C3%A9-scaled.jpg

# %%
# Pourcentage de ligne avec une valeur de nutriscore
a = df['nutriscore_grade'].isna().sum()
b = df.shape[0] 
c = ((b-a)/b)*100
print(c)
# Out:
# 36.43285193488322

# %%
df_nutriscore = df[ df['nutriscore_grade'].notna() ]
df_nutriscore.to_csv('df_nutriscore.csv')

# %%
df_nutriscore.head(50)
# Out:
#               code nutriscore_grade nova_group energy-kj_100g fat_100g  \
# 6    0000000000100                d        NaN            936      8.2
# 17   0000000000949                b        NaN            NaN      0.3
# 26   0000000001281                d        NaN            NaN       22
# 36   0000000001885                a        NaN            NaN        0
# 40   0000000002257                b        NaN            NaN     12.7
# 65   0000000005005                d        NaN            NaN       33
# 67   0000000005166                c        NaN            NaN       13
# 68   0000000005241                b        NaN            NaN        5
# 71   0000000005470                a          4            NaN      2.2
# 73   0000000005661                d        NaN            NaN       17
# 75   0000000007160                d        NaN            NaN       15
# 95   0000000012249                b        NaN            NaN      2.3
# 98    000000001231                e        NaN            NaN       29
# 116   000000001576                b        NaN            NaN      0.5
# 171   000000002218                d        NaN            NaN    42.75
# 178   000000002946                b        NaN            NaN     39.6
# 285  0000000043595                c          3            NaN        0
# 324  0000000125512                e        NaN            NaN       38
# 334   000000022524                c        NaN            NaN     91.5
# 338  0000000274722                b          4            450      2.2
# 339  0000000274739                b        NaN            455      4.2
# 341  0000000290616                c          4            NaN       12
# 348  0000000338219                e        NaN            NaN       31
# 354     0000000356                c        NaN            NaN       92
# 362  0000000491228                b          4         1952.4     15.3
# 367       00000006                c        NaN            NaN      5.3
# 377     0000001462                d        NaN            NaN        0
# 382  0000001938067                c          4            NaN     10.7
# 389       00000024                a          1            NaN      8.8
# 396       00000038                c        NaN            NaN      4.7
# 399  0000004302544                b          3            NaN     1.11
# 402        0000005                b          1            NaN      5.2
# 403     0000005013                e        NaN            NaN     64.5
# 406     0000005016                e          3           2318     53.2
# 408     0000005018                d          3           1104     27.4
# 410     0000005020                e        NaN            NaN     38.8
# 411  0000005029525                c        NaN            NaN      4.4
# 419  0000007020254                e          4            NaN        0
# 425  0000007818707                e        NaN            NaN        0
# 428  0000008237798                b          4            NaN     6.79
# 433  0000009125124                b          4            NaN      0.5
# 434  0000009336247                d          4            NaN        0
# 439  0000010068175                c        NaN            NaN      0.1
# 453  0000010166604                d        NaN            NaN    10.41
# 455  0000010166697                d          4            NaN    10.29
# 466  0000010206515                d          4            NaN     6.42
# 480  0000010216477                d        NaN            NaN      4.8
# 481  0000010216491                d        NaN            NaN      4.8
# 500  0000012167005                b          4            NaN        6
# 505       00000131                c        NaN            NaN        0
#
#     saturated-fat_100g carbohydrates_100g sugars_100g fiber_100g  \
# 6                  2.2                 29          22          0
# 17                 0.1                5.3         3.9        NaN
# 26                15.5               27.3        21.9        4.4
# 36                   0                 36          27        3.6
# 40                   1                3.9           1        NaN
# 65                21.6                0.1         0.1        NaN
# 67                   4                  3         0.9        NaN
# 68                 1.1               28.7           3        NaN
# 71                 0.5               25.2         0.6        1.6
# 73                 2.6                0.5         0.5        NaN
# 75                 7.5                  1           1        NaN
# 95                 2.3                1.8         1.4        NaN
# 98                  11                  0           0        NaN
# 116                0.1               0.01        0.01        NaN
# 171             17.275              0.475       0.075        NaN
# 178                5.8               42.8        12.8        NaN
# 285                  0              83.33       66.67         10
# 324                 36                 58          58        NaN
# 334               12.6                  0           0        NaN
# 338                0.9               15.3         0.5        0.5
# 339                2.1               12.5         1.4        1.8
# 341                  7                 23           0          2
# 348                 16                 59          22        NaN
# 354                 12                  0           0        NaN
# 362               11.2               75.5        69.8        0.1
# 367                3.4                 22          13        NaN
# 377                  0               56.8          56        NaN
# 382                  2               38.7        24.7          2
# 389                1.5               12.7         8.5        NaN
# 396                2.9                 25         2.1        NaN
# 399              0.333               53.3        1.11       2.22
# 402                1.7                0.1         0.1        NaN
# 403               10.1               11.8           1        NaN
# 406                9.6               11.7         0.5        1.3
# 408                3.9                1.8           0        3.5
# 410                5.6               17.9         9.4        NaN
# 411                0.6               35.9           3        NaN
# 419                  0                 14           0          0
# 425                  0               13.3        12.7        NaN
# 428               2.86               7.86       0.714      0.357
# 433                0.1                 93          66        NaN
# 434                  0               93.3        93.3        NaN
# 439                0.1                0.1         0.1        NaN
# 453               0.79              77.68       70.54        NaN
# 455               0.77              77.02       69.97        NaN
# 466               3.53              87.86       81.67          0
# 480                3.3               87.1        84.7        NaN
# 481                3.3               87.1        84.7        NaN
# 500                  1                 50          19          1
# 505                  0                 58          58        NaN
#
#     proteins_100g sodium_100g alcohol_100g
# 6             5.1        1.84          NaN
# 17            0.9       0.168          NaN
# 26            4.6        0.04          NaN
# 36            0.6           0          NaN
# 40            1.9       0.108          NaN
# 65             25        0.52          NaN
# 67             17        0.44          NaN
# 68            8.4      0.1868          NaN
# 71            9.5      0.1432          NaN
# 73             23           1          NaN
# 75             24         0.8          NaN
# 95            3.7        0.16          NaN
# 98             16        0.64          NaN
# 116           0.5       0.004          NaN
# 171         13.05        0.44          NaN
# 178           8.7        0.08          NaN
# 285             0           0          NaN
# 324             3         0.2          NaN
# 334             0       0.001          NaN
# 338           6.8        0.28          NaN
# 339           4.4        0.24          NaN
# 341            22       0.864          NaN
# 348           6.4       0.232          NaN
# 354             0           0          NaN
# 362           6.8         0.2          NaN
# 367           3.3       0.048          NaN
# 377             1           0          NaN
# 382          3.33       0.259          NaN
# 389             5           0          NaN
# 396            11         0.6          NaN
# 399            10        0.61          NaN
# 402          80.6        0.12          NaN
# 403           5.9        0.96          NaN
# 406           8.2        1.08          NaN
# 408           1.9        1.08          NaN
# 410           5.2       0.784          NaN
# 411           3.7        0.36          NaN
# 419             0         0.4          NaN
# 425             0        0.02          NaN
# 428          5.36         0.2          NaN
# 433           1.5       0.008          NaN
# 434             0           0          NaN
# 439           0.1      0.0004          NaN
# 453          4.29       0.084          NaN
# 455           4.2       0.084          NaN
# 466          0.03        0.04          NaN
# 480             0       0.048          NaN
# 481             0       0.048          NaN
# 500             7           0          NaN
# 505             0           0          NaN

# %%
df_nutriscore.shape[0]
# Out:
# 705955

# %%
import pandas as pd
df_nutriscore = pd.read_csv("df_nutriscore.csv")
# Out:
# /Users/benprieur/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import matplotlib.pyplot as plt
df_nutriscore.groupby('nutriscore_grade').nutriscore_grade.value_counts().plot.barh()
# Out:
# <AxesSubplot:ylabel='nutriscore_grade,nutriscore_grade'>

# %%
# https://medium.com/data-science-365/pandas-for-data-science-part-2-c12c3ee876c2
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Satured Fat')
plt.ylabel('Density')
sns.kdeplot(df_nutriscore['saturated-fat_100g'])
# Out:
# <AxesSubplot:xlabel='Satured Fat', ylabel='Density'>

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Fat')
plt.ylabel('Density')
sns.kdeplot(df_nutriscore['fat_100g'])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Carbohydrates')
plt.ylabel('Density')
sns.kdeplot(df_nutriscore['carbohydrates_100g'])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Sugar')
plt.ylabel('Density')
sns.kdeplot(df_nutriscore['sugars_100g'])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Proteins')
plt.ylabel('Density')
sns.kdeplot(df3['proteins_100g'])
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.xlim(0,100)
plt.xlabel('Sodium')
plt.ylabel('Density')
sns.kdeplot(df_nutriscore['sodium_100g'])
plt.show()

# %%
# Une incursion du côté du nova group
df_nutriscore_nova = df_nutriscore[ df_nutriscore['nova_group'].notna() ]
df_nutriscore_nova.to_csv('df_nutriscore_nova.csv')

# %%
import pandas as pd
df_nutriscore_nova = pd.read_csv("df_nutriscore_nova.csv")
# Out:
# /Users/benprieur/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_nutriscore_nova.shape[0]
# Out:
# 462468

# %%
import matplotlib.pyplot as plt
df_nutriscore_nova.groupby('nutriscore_grade').nutriscore_grade.value_counts().plot.barh()
# Out:
# <AxesSubplot:ylabel='nutriscore_grade,nutriscore_grade'>

# %%
import matplotlib.pyplot as plt
df_nutriscore_nova.groupby('nova_group').nova_group.value_counts().plot.barh()
# Out:
# <AxesSubplot:ylabel='nova_group,nova_group'>

# %%
# https://medium.com/swlh/how-to-run-chi-square-test-in-python-4e9f5d10249d
contigency= pd.crosstab(df_nutriscore_nova['nutriscore_grade'], df_nutriscore_nova['nova_group']) 
print(contigency)
# Out:
# nova_group          1.0   2.0    3.0     4.0
# nutriscore_grade
# a                 32873   302  21245   23658
# b                  7826   142  15326   35934
# c                  7079  2095  25003   62444
# d                  2783  1973  34992  101212
# e                  1628  1542  13281   71130

# %%
contigency_pct = pd.crosstab(df_nutriscore_nova['nutriscore_grade'], df_nutriscore_nova['nova_group'], normalize='index')
print(contigency_pct)
# Out:
# nova_group             1.0       2.0       3.0       4.0
# nutriscore_grade
# a                 0.421028  0.003868  0.272100  0.303005
# b                 0.132133  0.002398  0.258763  0.606706
# c                 0.073266  0.021683  0.258774  0.646278
# d                 0.019743  0.013997  0.248241  0.718019
# e                 0.018589  0.017607  0.151642  0.812162

# %%
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency_pct, annot=False, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='nova_group', ylabel='nutriscore_grade'>

# %%
from scipy.stats import chi2_contingency
c, p, dof, expected = chi2_contingency(contigency_pct) 
print(p)
# Out:
# 0.9999692943362465

# %%
# 0.9999692943362465 >> 0.01
# Le test n'est pas validé : pas d'indépendance ; nova et nutriscore sont corrélées.
